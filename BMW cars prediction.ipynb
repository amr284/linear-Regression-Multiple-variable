# %% [markdown]
# # BMW CARS PREDICTION

# %% [markdown]
# We have a dataset containing prices of used BMW cars. We are going to analyze this dataset and build a prediction function that can predict a price by taking mileage and age of the car as input. We will use sklearn train_test_split method to split training and testing dataset

# %% [markdown]
# ![download_10_0-sixteen_nine_1-sixteen_nine.jpg](attachment:download_10_0-sixteen_nine_1-sixteen_nine.jpg)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
# load the homeprices in the dataframe 
df = pd.read_csv("carprice.csv")
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %% [markdown]
# # Training And Testing Available Data

# %% [markdown]
#  stratgy is split data set into two parts where you use part of sample for training and
# and the remaining samples for testing your model

# %% [markdown]
# Training: We will train our model on this dataset
#
# Testing: We will use this subset to make actual predictions using trained model

# %%
"""using some matplotlib visulaiztion to figure out the relationship between dependent and independant variable"""
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])
plt.xlabel("Mileage ")
plt.ylabel("sell price $")
# Out:
# Text(0, 0.5, 'sell price $')

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])
plt.xlabel("age(years) ")
plt.ylabel("sell price $")
# Out:
# Text(0, 0.5, 'sell price $')

# %%
X = df[['Mileage','Age(yrs)']]
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y = df['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %% [markdown]
# use tain taste split method from sklearn
#  use x , y as an input and also you need to supply the ratio by which you are spreading ...&result what you get

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
# have ratio 80% f samples
X_train
# Out:
#     Mileage  Age(yrs)
# 8     91000         8
# 1     35000         3
# 0     69000         6
# 10    83000         7
# 3     22500         2
# 4     46000         4
# 19    52000         5
# 12    59000         5
# 6     52000         5
# 9     67000         6
# 16    28000         2
# 15    25400         3
# 17    69000         5
# 11    79000         7
# 7     72000         6
# 2     57000         5

# %%
# 20% train of samples
X_test
# Out:
#     Mileage  Age(yrs)
# 13    58780         4
# 18    87600         8
# 14    82450         7
# 5     59000         5

# %%
# 80%
y_train
# Out:
# 8     12000
# 1     34000
# 0     18000
# 10    18700
# 3     40000
# 4     31500
# 19    28200
# 12    26000
# 6     32000
# 9     22000
# 16    35500
# 15    35000
# 17    19700
# 11    19500
# 7     19300
# 2     26100
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 6     32000
# 8     12000
# 5     26750
# 14    19400
# 1     34000
# 7     19300
# Name: Sell Price($), dtype: int64

# %% [markdown]
# # let's use linear regression model

# %%
# linear regression model 
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
# Out:
# LinearRegression()

# %%
# train your model 
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([27242.90922922, 13298.19172894, 25217.05083965, 16658.56377662,
#        33934.71249044, 20568.81167289])

# %%
y_test
# Out:
# 7     19300
# 10    18700
# 5     26750
# 6     32000
# 3     40000
# 18    12800
# Name: Sell Price($), dtype: int64

# %%
# test accuracy of the model by calling score method
clf.score(X_test, y_test)
# Out:
# 0.9382465792067208
